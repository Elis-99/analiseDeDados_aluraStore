# %% [markdown]
# ### Importação dos dados

# %% [markdown]
# #1. Análise do faturamento

# %%
faturamento_loja1 = loja['Preço'].sum()
print(f'Faturamento Loja 1 (produtos): R$ {faturamento_loja1:.2f}')

faturamento_loja2 = loja2['Preço'].sum()
print(f'Faturamento Loja 2 (produtos): R$ {faturamento_loja2:.2f}')

faturamento_loja3 = loja3['Preço'].sum()
print(f'Faturamento Loja 3 (produtos): R$ {faturamento_loja3:.2f}')

faturamento_loja4 = loja4['Preço'].sum()
print(f'Faturamento Loja 4 (produtos): R$ {faturamento_loja4:.2f}')
# Out:
# Faturamento Loja 1 (produtos): R$ 1534509.12
# Faturamento Loja 2 (produtos): R$ 1488459.06
# Faturamento Loja 3 (produtos): R$ 1464025.03
# Faturamento Loja 4 (produtos): R$ 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
categorias_loja1 = loja['Categoria do Produto'].value_counts().idxmax()
print(f'Categoria mais vendida na Loja 1: {categorias_loja1}')

categorias_loja2 = loja2['Categoria do Produto'].value_counts().idxmax()
print(f'Categoria mais vendida na loja 2: {categorias_loja2}')

categorias_loja3 = loja3['Categoria do Produto'].value_counts().idxmax()
print(f'Categoria mais vendida na loja 3: {categorias_loja3}')

categorias_loja4 = loja4['Categoria do Produto'].value_counts().idxmax()
print(f'Categoria mais vendida da loja 4: {categorias_loja4}')
# Out:
# Categoria mais vendida na Loja 1: moveis
# Categoria mais vendida na loja 2: moveis
# Categoria mais vendida na loja 3: moveis
# Categoria mais vendida da loja 4: moveis

# %%
import matplotlib.pyplot as plt
faturamento_por_categoria_loja1 = loja.groupby('Categoria do Produto')['Preço'].sum()
faturamento_por_categoria_loja1.plot(kind='bar', figsize=(10, 6))
plt.title('Faturamento por Categoria na Loja 1')
plt.xlabel('Categoria do Produto')
plt.ylabel('Faturamento (R$)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
print('Avaliações Loja 1:\n', loja['Avaliação da compra'].value_counts().sort_index())
print('Avaliações Loja 2:\n', loja2['Avaliação da compra'].value_counts().sort_index())
print('Avaliação da Loja 3:\n', loja3['Avaliação da compra'].value_counts().sort_index())
print('Avaliação da Loja 4:\n', loja4['Avaliação da compra'].value_counts().sort_index())

print("\nMédia das avaliações Loja 1:", loja['Avaliação da compra'].mean())
print("Média das avaliações Loja 2:", loja2['Avaliação da compra'].mean())
print("Média das avaliações Loja 3:", loja3['Avaliação da compra'].mean())
print("Média das avaliações Loja 4:", loja4['Avaliação da compra'].mean())
# Out:
# Avaliações Loja 1:
#  Avaliação da compra
# 1     319
# 2      86
# 3     218
# 4     444
# 5    1292
# Name: count, dtype: int64
# Avaliações Loja 2:
#  Avaliação da compra
# 1     273
# 2      93
# 3     209
# 4     482
# 5    1302
# Name: count, dtype: int64
# Avaliação da Loja 3:
#  Avaliação da compra
# 1     297
# 2      79
# 3     193
# 4     434
# 5    1356
# Name: count, dtype: int64
# Avaliação da Loja 4:
#  Avaliação da compra
# 1     310
# 2      85
# 3     210
# 4     453
# 5    1300
# Name: count, dtype: int64
#
# Média das avaliações Loja 1: 3.976685036032217
# Média das avaliações Loja 2: 4.037303942348453
# Média das avaliações Loja 3: 4.048325561678677
# Média das avaliações Loja 4: 3.9957591178965224

# %%
plt.hist(loja['Avaliação da compra'], bins=5, edgecolor='black')
plt.title('Distribuição das Avaliações na Loja 1')
plt.xlabel('Avaliação')
plt.ylabel('Frequência')
plt.xticks(range(1, 6))
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
produtos_loja1 = loja['Produto'].value_counts().idxmax()
print(f'Produto mais vendido loja 1: {produtos_loja1}')

produtos_loja2 = loja2['Produto'].value_counts().idxmax()
print(f'Produto mais vendido loja 2: {produtos_loja2}')

produtos_loja3 = loja3['Produto'].value_counts().idxmax()
print(f'Produto mais vendido loja 3: {produtos_loja3}')

produtos_loja4 = loja4['Produto'].value_counts().idxmax()
print(f'Produto mais vendido loja 4: {produtos_loja4}')
# Out:
# Produto mais vendido loja 1: Micro-ondas
# Produto mais vendido loja 2: Iniciando em programação
# Produto mais vendido loja 3: Kit banquetas
# Produto mais vendido loja 4: Cama box

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio_loja1 = loja['Frete'].mean()
print(f'Frete médio da Loja 1: R$ {frete_medio_loja1:.2f}')

frete_medio_loja2 = loja2['Frete'].mean()
print(f'Frete médio da Loja 2: R$ {frete_medio_loja2:.2f}')

frete_medio_loja3 = loja3['Frete'].mean()
print(f'Frete médio da Loja 3: R$ {frete_medio_loja3:.2f}')

frete_medio_loja4 = loja4['Frete'].mean()
print(f'Frete médio da Loja 4: R$ {frete_medio_loja4:.2f}')
# Out:
# Frete médio da Loja 1: R$ 34.69
# Frete médio da Loja 2: R$ 33.62
# Frete médio da Loja 3: R$ 33.07
# Frete médio da Loja 4: R$ 31.28

# %%
frete_medio_por_estado_loja1 = loja.groupby('Local da compra')['Frete'].mean()
frete_medio_por_estado_loja1.plot(kind='line', figsize=(10, 6))
plt.title('Frete Médio por Estado na Loja 1')
plt.xlabel('Estado')
plt.ylabel('Frete Médio (R$)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# from re import M
# ##Relatório de Recomendação de Venda de Loja
#
# #### Loja 1
#
# *   **Faturamento:** R$ 1.534.509,12
# *   **Frete Médio:** R$ 34,69
# *   **Avaliação Média:** 3.97
# *   **Produto Mais Vendido:** Micro-ondas
# *   **Categoria Mais Vendida:** Móveis
#
# from re import M
# ##Relatório de Recomendação de Venda de Loja
#
# #### Loja 1
#
# *   **Faturamento:** R$ 1.534.509,12
# *   **Frete Médio:** R$ 34,69
# *   **Avaliação Média:** 3.97
# *   **Produto Mais Vendido:** Micro-ondas
# *   **Categoria Mais Vendida:** Móveis
#
# #### Loja 2
#
# *   **Faturamento:** R$ 1.488.459,06
# *   **Frete Médio:** R$ 33,62
# *   **Avaliação Média:** 4.03
# *   **Produto Mais Vendido:** Livro: Iniciando em Programação
# *   **Categoria Mais Vendida:** Móveis
#
# #### Loja 3
#
# *   **Faturamento:** R$ 1.464.025,03
# *   **Frete Médio:** R$ 33,07
# *   **Avaliação Média:** 4.04
# *   **Produto Mais Vendido:** Kit banquetas
# *   **Categoria Mais Vendida:** Móveis
#
# #### Loja 4
#
# *   **Faturamento:** R$ 1.384.497,58
# *   **Frete Médio:** R$ 31,28
# *   **Avaliação Média:** 3.99
# *   **Produto Mais Vendido:** Cama box
# *   **Categoria Mais Vendida:** Móveis
#
# Com base nos dados apresentados, a loja a ser vendida é a **Loja 4**.
#
#
# A Loja 4 apresenta o menor faturamento entre as quatro lojas, indicando um desempenho comercial inferior. Embora sua avaliação média seja similar à da Loja 1, o menor faturamento combinado com um frete médio mais baixo (o que pode indicar uma estratégia de preços menos eficiente ou um mix de produtos menos lucrativo) a torna a opção menos atraente para manter. Além disso, o produto mais vendido (Cama box), embora de valor relativamente alto, não compensa o volume de vendas inferior.
#
#
#
# ### Conclusão
#
# A venda da Loja 4 parece ser a decisão mais estratégica com base nos dados disponíveis. No entanto, recomenda-se uma análise mais aprofundada, levando em conta os fatores adicionais, antes de tomar a decisão final.
# *   **Produto Mais Vendido:** Livro: Iniciando em Programação
# *   **Categoria Mais Vendida:** Móveis
#
# #### Loja 3
#
# *   **Faturamento:** R$ 1.464.025,03
# *   **Frete Médio:** R$ 33,07
# *   **Avaliação Média:** 4.04
# *   **Produto Mais Vendido:** Kit banquetas
# *   **Categoria Mais Vendida:** Móveis
#
# #### Loja 4
#
# *   **Faturamento:** R$ 1.384.497,58
# *   **Frete Médio:** R$ 31,28
# *   **Avaliação Média:** 3.99
# *   **Produto Mais Vendido:** Cama box
# *   **Categoria Mais Vendida:** Móveis
#
# Com base nos dados apresentados, a loja a ser vendida é a **Loja 4**.
#
#
# A Loja 4 apresenta o menor faturamento entre as quatro lojas, indicando um desempenho comercial inferior. Embora sua avaliação média seja similar à da Loja 1, o menor faturamento combinado com um frete médio mais baixo (o que pode indicar uma estratégia de preços menos eficiente ou um mix de produtos menos lucrativo) a torna a opção menos atraente para manter. Além disso, o produto mais vendido (Cama box), embora de valor relativamente alto, não compensa o volume de vendas inferior.
#
#
#
# ### Conclusão
#
# A venda da Loja 4 parece ser a decisão mais estratégica com base nos dados disponíveis. No entanto, recomenda-se uma análise mais aprofundada, levando em conta os fatores adicionais, antes de tomar a decisão final.
